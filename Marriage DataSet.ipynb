# %% [markdown]
# # Applying Datascience to Matrimoney

# %% [markdown]
# ## Making Basic Imports

# %%
import numpy as np
import pandas as pd
import datetime
import os, glob
import math

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rcParams["figure.figsize"] = (20,10)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Reading the data from both csv and excel files but we'll only use the csv data.

# %%
df_csv = pd.read_csv("Marriage_Divorce_DB.csv")
df_xl = pd.read_excel("Marriage_Divorce_DB.xlsx")

# %% [markdown]
# ## Checking for null values to see if the data is clean of not

# %%
df_csv.isnull().sum()
# Out:
# Age Gap                                         0
# Education                                       0
# Economic Similarity                             0
# Social Similarities                             0
# Cultural Similarities                           0
# Social Gap                                      0
# Common Interests                                0
# Religion Compatibility                          0
# No of Children from Previous Marriage           0
# Desire to Marry                                 0
# Independency                                    0
# Relationship with the Spouse Family             0
# Trading in                                      0
# Engagement Time                                 0
# Love                                            0
# Commitment                                      0
# Mental Health                                   0
# The Sense of Having Children                    0
# Previous Trading                                0
# Previous Marriage                               0
# The Proportion of Common Genes                  0
# Addiction                                       0
# Loyalty                                         0
# Height Ratio                                    0
# Good Income                                     0
# Self Confidence                                 0
# Relation with Non-spouse Before Marriage        0
# Spouse Confirmed by Family                      0
# Divorce in the Family of Grade 1                0
# Start Socializing with the Opposite Sex Age     0
# Divorce Probability                             0
# dtype: int64

# %% [markdown]
# ### We see that we are not missing any data points and so we could go ahead with exploring the data

# %% [markdown]
# ## Exploring the data

# %%
df_csv.shape
# Out:
# (100, 31)

# %% [markdown]
# #### This means we have a 100 observations and 30 features and 1 target variable

# %%
df_csv.head()
# Out:
#     Age Gap  Education  Economic Similarity  Social Similarities  \
# 0  0.111633   1.915111            10.998678            76.456065
# 1  3.355384   2.957842            82.138120            48.656031
# 2  6.527365   2.772463            26.337826            59.356238
# 3  5.203075   1.729242            66.956033             5.472612
# 4  6.864962   4.370290            76.245035            26.797234
#
#    Cultural Similarities  Social Gap  Common Interests  \
# 0              47.847460   50.317656         88.099898
# 1              30.188517   54.114612         57.020971
# 2              10.340252   76.595377         80.590985
# 3               1.003407   55.071435         99.718078
# 4              93.291581   73.736241         52.896199
#
#    Religion Compatibility  No of Children from Previous Marriage  \
# 0               83.738075                               4.402822
# 1               98.408133                               4.367024
# 2               41.743462                               1.197120
# 3               70.493011                               3.392041
# 4               11.729729                               2.373553
#
#    Desire to Marry  Independency  Relationship with the Spouse Family  \
# 0        22.868019      1.269738                            73.206949
# 1        40.336843      1.658179                            91.666091
# 2        45.941845      1.766594                            17.926501
# 3         2.924863      1.065769                            17.036749
# 4        89.851492      1.103652                            81.656810
#
#    Trading in  Engagement Time       Love  Commitment  Mental Health  \
# 0   79.262360         5.424734  70.472234   76.106833      70.241804
# 1   63.763287         4.371315  60.818393   70.943766      80.029002
# 2   65.037501         6.514788  52.601832   96.092606      80.383938
# 3   32.493249         1.701053  80.600086   64.425022      63.755047
# 4   82.310898         9.012912  72.730718   73.944053      61.696215
#
#    The Sense of Having Children  Previous Trading  Previous Marriage  \
# 0                     86.138461         39.437387           2.766927
# 1                     60.668227         26.251231           1.308314
# 2                     28.225648          7.228832           4.203533
# 3                     45.348339         30.312101           2.117970
# 4                     98.688798         58.777743           1.151556
#
#    The Proportion of Common Genes  Addiction    Loyalty  Height Ratio  \
# 0                       21.032882   3.134119  49.648480     30.822948
# 1                       41.257627   2.067377  75.220699     68.268221
# 2                       23.917319   3.599095  22.551866     59.134874
# 3                       46.056440   1.549274  99.172136     40.984117
# 4                        2.743993   4.031738  21.629472     89.122381
#
#    Good Income  Self Confidence  Relation with Non-spouse Before Marriage  \
# 0    94.499164        45.964824                                  2.032610
# 1    41.102605        65.387715                                  1.053402
# 2    23.053577        84.271897                                  8.268308
# 3    43.400040        96.081229                                  5.852371
# 4    51.615509        53.330824                                  9.717223
#
#    Spouse Confirmed by Family  Divorce in the Family of Grade 1  \
# 0                    1.719332                          2.262242
# 1                    1.456192                          9.795998
# 2                    7.095241                          9.986173
# 3                    6.570749                          5.099396
# 4                    7.609152                          1.294295
#
#    Start Socializing with the Opposite Sex Age   Divorce Probability
# 0                                     24.356772             2.760190
# 1                                     19.667152             1.962979
# 2                                     15.522517             2.858803
# 3                                     34.665933             1.404621
# 4                                     22.545763             1.318819

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 31 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Age Gap                                       100 non-null    float64
#  1   Education                                     100 non-null    float64
#  2   Economic Similarity                           100 non-null    float64
#  3   Social Similarities                           100 non-null    float64
#  4   Cultural Similarities                         100 non-null    float64
#  5   Social Gap                                    100 non-null    float64
#  6   Common Interests                              100 non-null    float64
#  7   Religion Compatibility                        100 non-null    float64
#  8   No of Children from Previous Marriage         100 non-null    float64
#  9   Desire to Marry                               100 non-null    float64
#  10  Independency                                  100 non-null    float64
#  11  Relationship with the Spouse Family           100 non-null    float64
#  12  Trading in                                    100 non-null    float64
#  13  Engagement Time                               100 non-null    float64
#  14  Love                                          100 non-null    float64
#  15  Commitment                                    100 non-null    float64
#  16  Mental Health                                 100 non-null    float64
#  17  The Sense of Having Children                  100 non-null    float64
#  18  Previous Trading                              100 non-null    float64
#  19  Previous Marriage                             100 non-null    float64
#  20  The Proportion of Common Genes                100 non-null    float64
#  21  Addiction                                     100 non-null    float64
#  22  Loyalty                                       100 non-null    float64
#  23  Height Ratio                                  100 non-null    float64
#  24  Good Income                                   100 non-null    float64
#  25  Self Confidence                               100 non-null    float64
#  26  Relation with Non-spouse Before Marriage      100 non-null    float64
#  27  Spouse Confirmed by Family                    100 non-null    float64
#  28  Divorce in the Family of Grade 1              100 non-null    float64
#  29  Start Socializing with the Opposite Sex Age   100 non-null    float64
#  30  Divorce Probability                           100 non-null    float64
# dtypes: float64(31)
# memory usage: 24.3 KB

# %%
cols = df_csv.columns
print(cols)
# Out:
# Index(['Age Gap', 'Education', 'Economic Similarity', 'Social Similarities',
#        'Cultural Similarities', 'Social Gap', 'Common Interests',
#        'Religion Compatibility', 'No of Children from Previous Marriage',
#        'Desire to Marry', 'Independency',
#        'Relationship with the Spouse Family', 'Trading in', 'Engagement Time',
#        'Love', 'Commitment', 'Mental Health', 'The Sense of Having Children',
#        'Previous Trading', 'Previous Marriage',
#        'The Proportion of Common Genes', 'Addiction', 'Loyalty',
#        'Height Ratio', 'Good Income', 'Self Confidence',
#        'Relation with Non-spouse Before Marriage',
#        'Spouse Confirmed by Family', 'Divorce in the Family of Grade 1',
#        'Start Socializing with the Opposite Sex Age ', 'Divorce Probability'],
#       dtype='object')

# %%
# Replacing the blanks with underscore so as to better suit the programming parlance 
df_csv.columns = df_csv.columns.str.replace(' |-', '_', regex=True)

# %%
df_csv.describe().T
# Out:
#                                               count       mean        std  \
# Age_Gap                                       100.0   5.037214   2.566534
# Education                                     100.0   2.922620   1.105506
# Economic_Similarity                           100.0  57.034788  27.259673
# Social_Similarities                           100.0  55.238271  28.169047
# Cultural_Similarities                         100.0  45.354729  28.455983
# Social_Gap                                    100.0  52.610334  29.470198
# Common_Interests                              100.0  74.998784  14.075152
# Religion_Compatibility                        100.0  52.165466  30.141349
# No_of_Children_from_Previous_Marriage         100.0   3.004066   1.194009
# Desire_to_Marry                               100.0  47.692285  28.535831
# Independency                                  100.0   1.493801   0.299994
# Relationship_with_the_Spouse_Family           100.0  53.476052  27.781482
# Trading_in                                    100.0  52.271252  28.446594
# Engagement_Time                               100.0   5.827567   2.379149
# Love                                          100.0  59.265329  18.811133
# Commitment                                    100.0  68.636156  17.390125
# Mental_Health                                 100.0  74.356572  14.389239
# The_Sense_of_Having_Children                  100.0  57.366062  24.123363
# Previous_Trading                              100.0  38.811373  23.304382
# Previous_Marriage                             100.0   2.818610   1.080045
# The_Proportion_of_Common_Genes                100.0  24.727934  14.183313
# Addiction                                     100.0   3.006452   1.127506
# Loyalty                                       100.0  61.964665  22.697878
# Height_Ratio                                  100.0  48.718090  29.917348
# Good_Income                                   100.0  53.039097  28.347700
# Self_Confidence                               100.0  71.529986  17.082590
# Relation_with_Non_spouse_Before_Marriage      100.0   5.053511   2.860380
# Spouse_Confirmed_by_Family                    100.0   5.376485   2.537958
# Divorce_in_the_Family_of_Grade_1              100.0   5.449779   2.433747
# Start_Socializing_with_the_Opposite_Sex_Age_  100.0  28.459300   7.873343
# Divorce_Probability                           100.0   2.067222   0.562972
#
#                                                     min        25%        50%  \
# Age_Gap                                        0.111633   3.153033   4.961566
# Education                                      1.013645   2.030941   2.753493
# Economic_Similarity                            1.613919  36.649320  60.182815
# Social_Similarities                            2.521826  31.860366  58.038692
# Cultural_Similarities                          1.003407  20.722177  41.016170
# Social_Gap                                     3.646218  25.954739  52.240423
# Common_Interests                              52.306687  62.762560  74.259219
# Religion_Compatibility                         1.138927  26.676899  53.163896
# No_of_Children_from_Previous_Marriage          1.025752   2.100129   3.048906
# Desire_to_Marry                                2.924863  23.728733  44.910947
# Independency                                   1.004482   1.249035   1.524880
# Relationship_with_the_Spouse_Family            3.070854  32.955994  55.156674
# Trading_in                                     1.126438  31.763925  55.003363
# Engagement_Time                                1.172514   3.758004   5.882697
# Love                                          31.023961  42.351301  60.479591
# Commitment                                    40.693664  52.675083  69.724025
# Mental_Health                                 50.598478  62.528264  71.982772
# The_Sense_of_Having_Children                  10.315078  40.211360  56.837824
# Previous_Trading                               1.048182  19.485974  37.893739
# Previous_Marriage                              1.009834   1.955448   2.798133
# The_Proportion_of_Common_Genes                 1.478815  10.867125  23.709428
# Addiction                                      1.091781   2.072883   2.844901
# Loyalty                                       20.438638  44.512843  65.441168
# Height_Ratio                                   1.270146  19.504704  50.637680
# Good_Income                                    2.609887  28.356761  51.131364
# Self_Confidence                               40.477817  57.315001  72.731073
# Relation_with_Non_spouse_Before_Marriage       1.007064   2.523458   4.679590
# Spouse_Confirmed_by_Family                     1.201454   3.483035   5.381406
# Divorce_in_the_Family_of_Grade_1               1.009378   3.611658   5.708680
# Start_Socializing_with_the_Opposite_Sex_Age_  15.194998  22.260441  30.008330
# Divorce_Probability                            1.010215   1.605394   2.078625
#
#                                                     75%        max
# Age_Gap                                        6.904617   9.733494
# Education                                      3.910120   4.934219
# Economic_Similarity                           79.167894  98.862683
# Social_Similarities                           77.041343  99.892423
# Cultural_Similarities                         69.217013  99.753878
# Social_Gap                                    83.618457  99.538187
# Common_Interests                              85.019345  99.718078
# Religion_Compatibility                        77.570105  99.986393
# No_of_Children_from_Previous_Marriage          4.156573   4.964397
# Desire_to_Marry                               68.517372  99.948651
# Independency                                   1.762106   1.995283
# Relationship_with_the_Spouse_Family           78.940637  99.868774
# Trading_in                                    73.914554  99.634848
# Engagement_Time                                7.739037   9.805916
# Love                                          72.874860  98.758003
# Commitment                                    81.798322  99.460013
# Mental_Health                                 85.715811  98.348819
# The_Sense_of_Having_Children                  79.435255  98.688798
# Previous_Trading                              61.708235  79.126652
# Previous_Marriage                              3.584819   4.892221
# The_Proportion_of_Common_Genes                37.639455  48.892792
# Addiction                                      3.999592   4.992623
# Loyalty                                       81.229518  99.172136
# Height_Ratio                                  72.782038  97.268605
# Good_Income                                   78.188864  97.967418
# Self_Confidence                               86.362335  99.802517
# Relation_with_Non_spouse_Before_Marriage       7.799692   9.780034
# Spouse_Confirmed_by_Family                     7.261164   9.975198
# Divorce_in_the_Family_of_Grade_1               7.334295   9.986173
# Start_Socializing_with_the_Opposite_Sex_Age_  35.882111  39.721314
# Divorce_Probability                            2.573561   2.990040

# %% [markdown]
# ## Setting X as the features and y as the taget i.e. Divorce Probability

# %%
X , y = df_csv.iloc[:,:-1], df_csv.iloc[:,-1]

# %% [markdown]
# ## Insights from over seeing the data:
# ### We see that all the data is in float format rather than in string format, which makes it easier to deal with.

# %% [markdown]
# ## Now we try different feature resuction techniques to determine if we could drop some parameters that are not important to our target variable i.e. Divorce Probability

# %%
# We are goin to be runnning 3 different tests for feature selection. They are namely Boruta, 
# Chi square test(Pearson's coefficient) and Decision Trees.
# Lets make the required imports to run them.

 
from boruta import BorutaPy
from sklearn.feature_selection import RFE
from sklearn.feature_selection import chi2
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel 
from sklearn.svm import LinearSVR
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## First lets scale our data using the Standard or MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# You can choose either the standard scaler or the MinMaxScaler. I have selected MinMax, choice of which is just random. 

# scaler = StandardScaler()
scaler = MinMaxScaler()

X_scaled = scaler.fit_transform(X)
# Last column i.e. Divorce Probability is the target column so I have placed that in y while rest all are features that go in data X.

# %% [markdown]
# ## We could run a test train split on the data here, but as we are not building a model but just selecting features, I felt it was okay not to create a split. I have commented the code below that gives us a train test split. Incase you are building a model, please make sure to create a split and then predict the test results using the test data.

# %%
# # Preparing the data by creating a test train split
# from sklearn.model_selection import train_test_split


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %% [markdown]
# ## Now we will run a random forest regressor to get the important features

# %%
model_rf = SelectFromModel(RandomForestRegressor())

model_rf.fit(X_scaled,y)
# Out:
# SelectFromModel(estimator=RandomForestRegressor())

# %%
model_rf.transform(X_scaled)
# Out:
# array([[2.29932072e-01, 9.65026034e-02, 8.57419227e-01, 7.24562005e-01,
#         4.12411455e-01, 5.23563377e-01, 3.70996378e-01, 9.63628948e-01,
#         1.39566906e-01, 3.73548699e-01],
#        [4.95896009e-01, 8.28022874e-01, 8.48330522e-01, 9.15259725e-01,
#         8.38968061e-01, 2.50098807e-01, 6.95791021e-01, 4.03667305e-01,
#         9.78814788e-01, 1.82341048e-01],
#        [4.48612536e-01, 2.54233630e-01, 4.35094596e-02, 1.53470726e-01,
#         4.73246611e-01, 6.42762299e-01, 2.68402615e-02, 2.14389887e-01,
#         1.00000000e+00, 1.33537715e-02],
#        [1.82523479e-01, 6.71906886e-01, 6.00787588e-01, 1.44278879e-01,
#         9.40178993e-01, 1.17280591e-01, 1.00000000e+00, 4.27760166e-01,
#         4.55621218e-01, 7.93879317e-01],
#        [8.56161570e-01, 7.67424826e-01, 3.42199361e-01, 8.11855839e-01,
#         2.66836515e-02, 7.53672587e-01, 1.51248764e-02, 5.13914542e-01,
#         3.17392865e-02, 2.99709269e-01],
#        [2.01879744e-01, 4.86543286e-01, 8.16320056e-01, 3.62091773e-01,
#         7.62294202e-01, 3.73109921e-01, 8.13757128e-01, 7.33161600e-01,
#         4.07198757e-01, 6.29811443e-02],
#        [4.73388101e-01, 9.30430481e-01, 6.82748498e-01, 9.94265953e-01,
#         4.81626802e-01, 9.36557054e-02, 2.83735956e-01, 9.11167559e-01,
#         7.76850180e-01, 9.18626342e-01],
#        [4.38935354e-01, 8.31498300e-01, 7.26609893e-01, 7.20894577e-01,
#         6.15641337e-01, 2.51980989e-01, 4.73126448e-01, 6.03944940e-02,
#         1.82687133e-01, 8.91357255e-01],
#        [6.19771024e-01, 8.06896588e-01, 7.84225550e-02, 6.25382368e-01,
#         7.10738208e-01, 3.30105106e-01, 2.18331763e-01, 4.98995176e-01,
#         9.06756848e-01, 1.20103973e-03],
#        [8.84882817e-01, 5.70425965e-01, 7.29643245e-01, 6.18213126e-01,
#         1.42437292e-01, 4.41660712e-01, 6.18427229e-02, 7.25460044e-01,
#         2.39158530e-01, 9.84211786e-02],
#        [6.19225290e-01, 6.41716465e-01, 8.81427347e-01, 2.33759970e-01,
#        [8.35915238e-01, 6.96388753e-02, 8.17158478e-01, 1.86370287e-01,
#         1.65467341e-02, 7.09246685e-01, 2.25702638e-01, 1.90323468e-02,
#         6.93770361e-01, 4.38387310e-01],
#        [5.40879992e-01, 5.98448724e-01, 7.85015163e-01, 1.16283072e-01,
#         1.54451545e-01, 2.91932188e-01, 4.01650927e-01, 4.39628767e-02,
#         2.38800483e-01, 8.75142093e-01],
#        [5.10779469e-02, 3.62647939e-01, 9.61734457e-02, 7.83567969e-01,
#         4.64477451e-01, 8.77249256e-01, 7.86621360e-03, 3.04237367e-01,
#         5.75859256e-01, 5.52737271e-02],
#        [1.64443019e-01, 7.46780075e-01, 5.23856371e-01, 9.55238366e-01,
#         8.55567683e-01, 9.07473614e-03, 7.38898317e-01, 7.74312289e-01,
#         3.13999035e-01, 1.69746497e-01],
#        [5.29032748e-01, 5.68593999e-01, 2.96178400e-01, 5.45339282e-01,
#         7.29701880e-01, 4.48187290e-01, 1.97709645e-01, 5.55206479e-01,
#         7.04444011e-01, 6.32909326e-01]])

# %%
df_feat_impt = pd.DataFrame({"Feature Name" : X.columns , "Importance" : model_rf.get_support()})

# %%
df_feat_impt
# Out:
#                                     Feature Name  Importance
# 0                                        Age_Gap       False
# 1                                      Education        True
# 2                            Economic_Similarity        True
# 3                            Social_Similarities       False
# 4                          Cultural_Similarities       False
# 5                                     Social_Gap       False
# 6                               Common_Interests       False
# 7                         Religion_Compatibility       False
# 8          No_of_Children_from_Previous_Marriage        True
# 9                                Desire_to_Marry       False
# 10                                  Independency       False
# 11           Relationship_with_the_Spouse_Family        True
# 12                                    Trading_in       False
# 13                               Engagement_Time       False
# 14                                          Love       False
# 15                                    Commitment       False
# 16                                 Mental_Health       False
# 17                  The_Sense_of_Having_Children       False
# 18                              Previous_Trading       False
# 19                             Previous_Marriage       False
# 20                The_Proportion_of_Common_Genes        True
# 21                                     Addiction        True
# 22                                       Loyalty        True
# 23                                  Height_Ratio       False
# 24                                   Good_Income        True
# 25                               Self_Confidence       False
# 26      Relation_with_Non_spouse_Before_Marriage       False
# 27                    Spouse_Confirmed_by_Family       False
# 28              Divorce_in_the_Family_of_Grade_1        True
# 29  Start_Socializing_with_the_Opposite_Sex_Age_        True

# %%
rf_feats = [x for i,x in enumerate(df_feat_impt["Feature Name"]) if df_feat_impt.iloc[i,-1] == True]

# %%
# We then print a list of important features according to RandomForest Regressor
rf_feats
# Out:
# ['Education',
#  'Economic_Similarity',
#  'No_of_Children_from_Previous_Marriage',
#  'Relationship_with_the_Spouse_Family',
#  'The_Proportion_of_Common_Genes',
#  'Addiction',
#  'Loyalty',
#  'Good_Income',
#  'Divorce_in_the_Family_of_Grade_1',
#  'Start_Socializing_with_the_Opposite_Sex_Age_']

# %% [markdown]
# ## Now we run boruta on top of RandomForestRegressor to get another list of features

# %%
# We need to convert our features and target into array or martix format. Boruta doesn't work with dataframe format.
features = np.array(X_scaled)
target = np.array(y)

# %%
#We will run Boruta on top of a Random Forest Classifier
rf = RandomForestRegressor()

# %%
boruta_feature_selector = BorutaPy(rf, random_state=200, max_iter=50, verbose=2, perc=75)
boruta_feature_selector.fit(features, target)
# Out:
# Iteration: 	1 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	2 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	3 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	4 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	5 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	6 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	7 / 50
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	8 / 50
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	15
# Iteration: 	9 / 50
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	15
# Iteration: 	10 / 50
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	15
# Iteration: 	11 / 50
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	15
# Iteration: 	12 / 50
# Confirmed: 	4
# Tentative: 	11
# Rejected: 	15
# Iteration: 	13 / 50
# Confirmed: 	4
# Tentative: 	11
# Rejected: 	15
# Iteration: 	14 / 50
# Confirmed: 	4
# Tentative: 	11
# Rejected: 	15
# Iteration: 	15 / 50
# Confirmed: 	4
# Tentative: 	11
# Rejected: 	15
# Iteration: 	16 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	17 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	18 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	19 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	20 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	21 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	22 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	23 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	24 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	25 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	26 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	27 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	28 / 50
# Confirmed: 	4
# Tentative: 	10
# Rejected: 	16
# Iteration: 	29 / 50
# Confirmed: 	5
# Tentative: 	9
# Rejected: 	16
# Iteration: 	30 / 50
# Confirmed: 	5
# Tentative: 	9
# Rejected: 	16
# Iteration: 	31 / 50
# Confirmed: 	5
# Tentative: 	9
# Rejected: 	16
# Iteration: 	32 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	33 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	34 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	35 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	36 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	37 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	38 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	39 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	40 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	41 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	42 / 50
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	16
# Iteration: 	43 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	44 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	45 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	46 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	47 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	48 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
# Iteration: 	49 / 50
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	17
#
#
# BorutaPy finished running.
#
# Iteration: 	50 / 50
# Confirmed: 	7
# Tentative: 	3
# Rejected: 	17
# BorutaPy(estimator=RandomForestRegressor(n_estimators=1000,
#                                          random_state=RandomState(MT19937) at 0x28EEFD21C40),
#          max_iter=50, perc=75,
#          random_state=RandomState(MT19937) at 0x28EEFD21C40, verbose=2)

# %%
df_feat_impt = pd.DataFrame({"Feature Name" : X.columns , "Importance" : boruta_feature_selector.support_})
df_feat_impt
# Out:
#                                     Feature Name  Importance
# 0                                        Age_Gap       False
# 1                                      Education        True
# 2                            Economic_Similarity       False
# 3                            Social_Similarities        True
# 4                          Cultural_Similarities       False
# 5                                     Social_Gap       False
# 6                               Common_Interests       False
# 7                         Religion_Compatibility       False
# 8          No_of_Children_from_Previous_Marriage        True
# 9                                Desire_to_Marry       False
# 10                                  Independency       False
# 11           Relationship_with_the_Spouse_Family       False
# 12                                    Trading_in       False
# 13                               Engagement_Time       False
# 14                                          Love       False
# 15                                    Commitment       False
# 16                                 Mental_Health       False
# 17                  The_Sense_of_Having_Children       False
# 18                              Previous_Trading       False
# 19                             Previous_Marriage       False
# 20                The_Proportion_of_Common_Genes        True
# 21                                     Addiction        True
# 22                                       Loyalty        True
# 23                                  Height_Ratio       False
# 24                                   Good_Income        True
# 25                               Self_Confidence       False
# 26      Relation_with_Non_spouse_Before_Marriage       False
# 27                    Spouse_Confirmed_by_Family       False
# 28              Divorce_in_the_Family_of_Grade_1       False
# 29  Start_Socializing_with_the_Opposite_Sex_Age_       False

# %%
boruta_feats = [x for i,x in enumerate(df_feat_impt["Feature Name"]) if df_feat_impt.iloc[i,-1] == True]

# %%
# Important features according to Boruta
boruta_feats
# Out:
# ['Education',
#  'Social_Similarities',
#  'No_of_Children_from_Previous_Marriage',
#  'The_Proportion_of_Common_Genes',
#  'Addiction',
#  'Loyalty',
#  'Good_Income']

# %% [markdown]
# ## RFE (Recursive Feature Elimination) to decide the features that are important

# %%
# We are using support vector regressor as model and top it with RFE to get the best 10 features.
svm = LinearSVR()
rfe = RFE(svm ,n_features_to_select=10)

# %%
rfe.fit(X_scaled,y)
# Out:
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\Users\f2013\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# RFE(estimator=LinearSVR(), n_features_to_select=10)

# %%
df_feat_impt = pd.DataFrame({"Feature Name" : X.columns , "Importance" : rfe.support_})
df_feat_impt
# Out:
#                                     Feature Name  Importance
# 0                                        Age_Gap       False
# 1                                      Education        True
# 2                            Economic_Similarity       False
# 3                            Social_Similarities       False
# 4                          Cultural_Similarities        True
# 5                                     Social_Gap        True
# 6                               Common_Interests       False
# 7                         Religion_Compatibility       False
# 8          No_of_Children_from_Previous_Marriage       False
# 9                                Desire_to_Marry        True
# 10                                  Independency       False
# 11           Relationship_with_the_Spouse_Family        True
# 12                                    Trading_in       False
# 13                               Engagement_Time       False
# 14                                          Love       False
# 15                                    Commitment        True
# 16                                 Mental_Health        True
# 17                  The_Sense_of_Having_Children       False
# 18                              Previous_Trading       False
# 19                             Previous_Marriage       False
# 20                The_Proportion_of_Common_Genes       False
# 21                                     Addiction        True
# 22                                       Loyalty       False
# 23                                  Height_Ratio       False
# 24                                   Good_Income       False
# 25                               Self_Confidence       False
# 26      Relation_with_Non_spouse_Before_Marriage        True
# 27                    Spouse_Confirmed_by_Family       False
# 28              Divorce_in_the_Family_of_Grade_1       False
# 29  Start_Socializing_with_the_Opposite_Sex_Age_        True

# %%
rfe_feats = [x for i,x in enumerate(df_feat_impt["Feature Name"]) if df_feat_impt.iloc[i,-1] == True]

# %%
rfe_feats
# Out:
# ['Education',
#  'Cultural_Similarities',
#  'Social_Gap',
#  'Desire_to_Marry',
#  'Relationship_with_the_Spouse_Family',
#  'Commitment',
#  'Mental_Health',
#  'Addiction',
#  'Relation_with_Non_spouse_Before_Marriage',
#  'Start_Socializing_with_the_Opposite_Sex_Age_']

# %%
df = pd.DataFrame({"Boruta": pd.Series(boruta_feats), "RandomForest": pd.Series(rf_feats),"RFE": pd.Series(rfe_feats)})

# %%
most_imp_features = []
for i,name in enumerate(df["RandomForest"]):
    if (name in list(df["Boruta"])) and (name in list(df["RFE"])):
        most_imp_features.append(name)

# %%
most_imp_features
# Out:
# ['Education', 'Addiction']

# %%
df
# Out:
#                                   Boruta  \
# 0                              Education
# 1                    Social_Similarities
# 2  No_of_Children_from_Previous_Marriage
# 3         The_Proportion_of_Common_Genes
# 4                              Addiction
# 5                                Loyalty
# 6                            Good_Income
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#                                    RandomForest  \
# 0                                     Education
# 1                           Economic_Similarity
# 2         No_of_Children_from_Previous_Marriage
# 3           Relationship_with_the_Spouse_Family
# 4                The_Proportion_of_Common_Genes
# 5                                     Addiction
# 6                                       Loyalty
# 7                                   Good_Income
# 8              Divorce_in_the_Family_of_Grade_1
# 9  Start_Socializing_with_the_Opposite_Sex_Age_
#
#                                             RFE
# 0                                     Education
# 1                         Cultural_Similarities
# 2                                    Social_Gap
# 3                               Desire_to_Marry
# 4           Relationship_with_the_Spouse_Family
# 5                                    Commitment
# 6                                 Mental_Health
# 7                                     Addiction
# 8      Relation_with_Non_spouse_Before_Marriage
# 9  Start_Socializing_with_the_Opposite_Sex_Age_
